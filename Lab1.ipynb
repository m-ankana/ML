# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# PROPERTIES OF MATRIX AND ARRAY
x=np.array([1,2])
print(x)
# Out:
# [1 2]

# %%
y=np.array([-2,1])
print(y)
# Out:
# [-2  1]

# %%
a=np.dot(x,y)
print(a) 
# because x and y does not follow matrix multiplication rule
# Out:
# 0

# %%
print(x.T @ y)
# because @ doesn't work for 1D array!
# Out:
# 0

# %%
b = np.linalg.norm(x)
print(b)
c = np.sqrt(x[0]**2 + x[1]**2)
print(b, c)
# b=c norm of vector is the square root of sum of squared vector values
# Out:
# 2.23606797749979
# 2.23606797749979 2.23606797749979

# %%
theta = np.arccos(np.dot(x,y) / (np.linalg.norm(x) * np.linalg.norm(x)))
print(theta*180/np.pi)
# formula to calculate theta
# Out:
# 90.0

# %%
B = np.array([[3,2,1], [2,6,5], [1,5,9]], dtype=float)
print(B)
# Out:
# [[3. 2. 1.]
#  [2. 6. 5.]
#  [1. 5. 9.]]

# %%
print(B - B.T)
# property matrix - transpose of matrix =0
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
z = np.random.rand(3)
# random values generated 
print(z)
v = B @ z
print(B)
print(v)
print(B.shape, z.shape, v.shape)
# Out:
# [0.49524777 0.33149288 0.81518716]
# [[3. 2. 1.]
#  [2. 6. 5.]
#  [1. 5. 9.]]
# [2.96391624 7.05538863 9.4893966 ]
# (3, 3) (3,) (3,)

# %%
print(z.T @ B @ z)
# Out:
# 11.542318273576669

# %%
print(B)
# sum along the diagonal 
print(np.trace(B))
# Out:
# [[3. 2. 1.]
#  [2. 6. 5.]
#  [1. 5. 9.]]
# 18.0

# %%
print(np.linalg.det(B))
# prints the determinant of B.
# Out:
# 65.00000000000004

# %%
D, U = np.linalg.eig(B)
# Compute the eigenvalues and right eigenvectors of a square array.
# D= eigen values
# U= eigen vector
print(D)
# Out:
# [13.11766327  3.44324229  1.43909444]

# %%
print(U) 
# eigen vector
# Out:
# [[-0.19527095 -0.74608451  0.63657455]
#  [-0.59990492 -0.42261825 -0.67934373]
#  [-0.77587586  0.5145403   0.3650547 ]]

# %%
# [ : , 0 ] means (more or less) [ first_row:last_row , column_0 ]. If you have a 2-dimensional list/matrix/array, this notation will give you all the values in column 0 (from all rows).
print(np.dot(U[:,0], U[:,1]))
# Out:
# -1.6653345369377348e-16

# %%
U[:,1]
# Out:
# array([-0.74608451, -0.42261825,  0.5145403 ])

# %%
print(U @ U.T)
# Out:
# [[ 1.00000000e+00  1.66533454e-16 -8.32667268e-17]
#  [ 1.66533454e-16  1.00000000e+00 -1.38777878e-16]
#  [-8.32667268e-17 -1.38777878e-16  1.00000000e+00]]

# %%
# What do you observe for the last command above (i.e. print(np.dot(U[:,0], U[:,1])))? Can
# you formally prove that this is the result you would expect for the specific structure in the
# matrix B?

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.rand(1000,1)
fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(10,4))
n1bins, n2bins = 4, 40
ax[0].hist(x, bins=n1bins)
ax[0].set_ylim(0,250)
ax[0].set_xlabel("Bins", fontsize=16)
ax[0].set_ylabel("Count", fontsize=16)
ax[0].tick_params(axis='both', which='major', labelsize=14)
ax[0].set_title("Histogram: bins=%4d"%(n1bins), fontsize=16)
ax[1].hist(x, bins=n2bins)
ax[1].set_ylim(0,250)
ax[1].set_xlabel("Bins", fontsize=16)
ax[1].set_ylabel("Count", fontsize=16)
ax[1].tick_params(axis='both', which='major', labelsize=14)
ax[1].set_title("Histogram: bins=%4d"%(n2bins), fontsize=16)
plt.savefig("histograms_uniform.png")
plt.tight_layout()
# Think through the following:
#  Though the data is from a uniform distribution, the histogram does not appear flat. Why?
#  Every time you run it, the histogram looks slightly different? Why?

# %%
x = np.random.rand(100000,1)
fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(10,4))
n1bins, n2bins = 4, 40
ax[0].hist(x, bins=n1bins)
ax[0].set_ylim(0,250)
ax[0].set_xlabel("Bins", fontsize=16)
ax[0].set_ylabel("Count", fontsize=16)
ax[0].tick_params(axis='both', which='major', labelsize=14)
ax[0].set_title("Histogram: bins=%4d"%(n1bins), fontsize=16)
ax[1].hist(x, bins=n2bins)
ax[1].set_ylim(0,250)
ax[1].set_xlabel("Bins", fontsize=16)
ax[1].set_ylabel("Count", fontsize=16)
ax[1].tick_params(axis='both', which='major', labelsize=14)
ax[1].set_title("Histogram: bins=%4d"%(n2bins), fontsize=16)
plt.savefig("histograms_uniform.png")
plt.tight_layout()
#  Do the above observations change (if so how) if you had started with more data (i.e.
# 100, 000 instead of 1000?

# %%
N = 1000
x1 = np.zeros(N)
for n in range(N):
    x1[n] = np.sum(np.random.rand(12,1)) - np.sum(np.random.rand(12,1))
fig, ax = plt.subplots(figsize=(5,5))
ax.hist(x1, 20)
# What do you observe? How does the resulting histogram change when you change the number
# of uniform random numbers you add and subtract (i.e. fewer numbers than 12)
# Out:
# (array([  4.,   8.,   6.,  18.,  33.,  40.,  67.,  80.,  96.,  99., 101.,
#         114.,  92.,  85.,  58.,  42.,  24.,  18.,  11.,   4.]),
#  array([-4.11220872, -3.71363144, -3.31505417, -2.9164769 , -2.51789963,
#         -2.11932235, -1.72074508, -1.32216781, -0.92359054, -0.52501326,
#         -0.12643599,  0.27214128,  0.67071855,  1.06929583,  1.4678731 ,
#          1.86645037,  2.26502764,  2.66360492,  3.06218219,  3.46075946,
#          3.85933673]),
#  <BarContainer object of 20 artists>)

# %%
# Uncertainty in Estimation
MaxTrial = 2000
sampleSizeRange = np.linspace(100, 200, 40)
plotVar = np.zeros(len(sampleSizeRange))
for sSize in range(len(sampleSizeRange)):
    numSamples = int(sampleSizeRange[sSize])
    vStrial = np.zeros(MaxTrial)
    for trial in range(MaxTrial):
        xx = np.random.randn(numSamples,1)
        vStrial[trial] = np.var(xx)
    plotVar[sSize] = np.var(vStrial)
fig, ax = plt.subplots(figsize=(4,4))
ax.plot((plotVar))

# %%
# Bi-variate Gaussian Distribution
def gauss2D(x, m, C):
    Ci = np.linalg.inv(C)
    dC = np.linalg.det(C1)
    num = np.exp(-0.5 * np.dot((x-m).T, np.dot(Ci, (x-m))))
    den = 2 * np.pi * dC
    return num/den
def twoDGaussianPlot (nx, ny, m, C):
    x = np.linspace(-5, 5, nx)
    y = np.linspace(-5, 5, ny)
    X, Y = np.meshgrid(x, y, indexing='ij')
    Z = np.zeros([nx, ny])
    for i in range(nx):
        for j in range(ny):
            xvec = np.array([X[i,j], Y[i,j]])
            Z[i,j] = gauss2D(xvec, m, C)
    return X, Y, Z

# Plot contours
#
nx, ny = 50, 40
m1 = np.array([0,2])
C1 = np.array([[2,1], [1,2]], np.float32)
Xp, Yp, Zp = twoDGaussianPlot (nx, ny, m1, C1)
plt.contour(Xp, Yp, Zp, 5)

# %%
nx, ny = 50,40
m1 = np.array([2.4,3.2])
C1 = np.array([[2,-1], [-1,2]], np.float32)
Xp, Yp, Zp = twoDGaussianPlot (nx, ny, m1, C1)
plt.contour(Xp, Yp, Zp, 5)

# %%
nx, ny = 50,40
m1 = np.array([1.2,0.2])
C1 = np.array([[2,0], [0,4]], np.float32)
Xp, Yp, Zp = twoDGaussianPlot (nx, ny, m1, C1)
plt.contour(Xp, Yp, Zp, 5)

# %%
nx, ny = 50,40
m1 = np.array([2.4,3.2])
C1 = np.array([[2,0], [0,2]], np.float32)
Xp, Yp, Zp = twoDGaussianPlot (nx, ny, m1, C1)
plt.contour(Xp, Yp, Zp, 5)

# %%
# Sampling from a multi variate gaussian
C = np.array([[2.0,1.0], [1.0,2]])
A = np.linalg.cholesky(C)
print(A @ A.T)
# Out:
# [[2. 1.]
#  [1. 2.]]

# %%
X = np.random.randn(1000,2)
Y = X @ A
print(X.shape)
print(Y.shape)
# Out:
# (1000, 2)
# (1000, 2)

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(X[:,0], X[:,1], c="c", s=4)
ax.scatter(Y[:,0], Y[:,1], c="m", s=4)
ax.set_xlim(-6, 6)
ax.set_ylim(-6, 6)
# Out:
# (-6.0, 6.0)

# %%
# Distribution of projections
theta = np.pi/3
u = [np.sin(theta), np.cos(theta)]
print("The vector: ", u)
print("Magnitude : ", np.sqrt(u[0]**2 + u[1]**2))
print("Angle : ", theta*180/np.pi)
# Out:
# The vector:  [0.8660254037844386, 0.5000000000000001]
# Magnitude :  1.0
# Angle :  59.99999999999999

# %%
yp = Y @ u
print(yp.shape)
print("Projected variance: ", np.var(yp))
# Out:
# (1000,)
# Projected variance:  2.8815987169722486

# %%
# Store projected variances in pVars & plot
#
nPoints = 50
pVars = np.zeros(nPoints)
thRange = np.linspace(0, 2*np.pi, nPoints)
for n in range(nPoints):
    theta = thRange[n]
    u = [np.sin(theta), np.cos(theta)]
    pVars[n] = np.var(Y @ u)
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(pVars)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-e647c4fc5a6b> in <module>
# ----> 1 fig.max()
#
# AttributeError: 'Figure' object has no attribute 'max'
